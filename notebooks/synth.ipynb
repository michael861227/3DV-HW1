# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import torch
from torchvision.utils import save_image

# %%
from pytorch3d.structures import Meshes
from pytorch3d.io import load_obj
from pytorch3d.renderer import TexturesVertex
from pytorch3d.ops import sample_points_from_meshes

import trimesh
from trimesh.voxel import creation
from trimesh.viewer import in_notebook

from scene import Scene

# %%
device = torch.device('cuda:0')
obj_list = sorted(glob.glob('./data/chair/*/*.obj'))

# %%
db = sorted(glob.glob(os.path.join("./data/chair", '*/')))

print(os.path.join(db[2], 'view.png'))
print(db[2].split('/'))
# Out:
# ./data/chair/100b18376b885f206ae9ad7e32c4139d/view.png
# ['.', 'data', 'chair', '100b18376b885f206ae9ad7e32c4139d', '']

# %%
def load_mesh(obj, device):
    verts, faces, _ = load_obj(obj, load_textures=False)
    faces_idx = faces.verts_idx

    verts_rgb = torch.ones_like(verts)[None]  # (1, V, 3)
    textures = TexturesVertex(verts_features=verts_rgb.to(device))

    mesh = Meshes(
        verts=[verts.to(device)],
        faces=[faces_idx.to(device)],
        textures=textures
    )

    return mesh

# %%
scene = Scene(device=device)
#scene.set_cam(1.7, 50, 90)
scene.set_light(location=[[0.0, 0.0, 0.0]])
scene.set_rasterizer(image_size=256)
#scene.set_renderer()

# %%
import shutil
import os

pbar = tqdm(obj_list)

for obj in pbar:
    id = obj.split('/')[3]
    path = obj.replace('model.obj', '')
    pbar.set_description(f"Processing: {id}")

    if not os.path.exists(os.path.join(path, "voxel.npy")):
        print(path)
    
#     if os.path.exists(os.path.join(path, "model.mtl")):
#         os.remove(os.path.join(path, "model.mtl"))

#     if os.path.exists(os.path.join(path, "models/")):
#         print(os.path.join(path, "models/"))
#         os.rmdir(os.path.join(path, "models/"))

#     if os.path.exists(os.path.join(path, "images/")):
#         print(os.path.join(path, "images/"))
#         shutil.rmtree(os.path.join(path, "images/"))
# Out:
#   0%|          | 0/6778 [00:00<?, ?it/s]

# %%
pbar = tqdm(obj_list[4480:])

for obj in pbar:
    id = obj.split('/')[3]
    path = obj.replace('model.obj', '')
    pbar.set_description(f"Processing: {id}")

    # mesh = load_mesh(obj, device)
    # elev = np.random.randint(0, 45, 1)
    # azim = np.random.randint(30, 150, 1)
    # scene.set_cam(1.0, elev, azim)
    # scene.set_renderer()
    # image = scene.renderer(mesh)
    # image = image[0, ..., :3].permute(2, 0, 1)
    # save_image(image, path+'view.png')

    # point_cloud = sample_points_from_meshes(mesh,num_samples=2048)
    # point_cloud = point_cloud.squeeze(0)
    # np.save(path + 'point_cloud',point_cloud.cpu().numpy())
    # mesh = tri_load_obj(path, skip_materials=False)
    mesh = trimesh.load(obj, file_type='obj', resolver=None, force='mesh', skip_materials=True)
    # print(type(mesh))
    voxel = creation.local_voxelize(mesh, mesh.centroid, mesh.extents.max() / 32, radius=16, fill=True)
    # print(voxel.shape)
    np_voxel = np.array(voxel.encoding.data, dtype=np.bool)
    # np_voxel = np.array(voxel.matrix)
    np.save(path + 'voxel',np_voxel)
    # print(np_voxel)
    # is_nt = in_notebook()
    # print(is_nt)
    # voxel.show()
    # ax = plt.figure().add_subplot(projection='3d')
    # ax.voxels(np_voxel, facecolors='red', edgecolor='k')
# Out:
#   0%|          | 0/2298 [00:00<?, ?it/s]
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_16)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_0_16)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# specified material (material)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_3_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3)  not loaded!
# specified material (material_2)  not loaded!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_3_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_5_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_6_24)  not loaded!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0)  not loaded!
# specified material (material)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_5_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_5_24)  not loaded!
# specified material (material_6_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_4_24)  not loaded!
# specified material (material_3_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_3_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_5_16)  not loaded!
# specified material (material_8_16)  not loaded!
# specified material (material_4_16)  not loaded!
# specified material (material_7_16)  not loaded!
# specified material (material_6_16)  not loaded!
# specified material (material_3_16)  not loaded!
# specified material (material_10_24)  not loaded!
# specified material (material_11_24)  not loaded!
# specified material (material_14_24)  not loaded!
# specified material (material_14_16)  not loaded!
# specified material (material_15_16)  not loaded!
# specified material (material_1_16)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_16_16)  not loaded!
# specified material (material_18_16)  not loaded!
# specified material (material_22_16)  not loaded!
# specified material (material_19_24)  not loaded!
# specified material (material_2_16)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_5_24)  not loaded!
# specified material (material_7_24)  not loaded!
# specified material (material_9_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_6_24)  not loaded!
# specified material (material_8_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_12)  not loaded!
# specified material (material_11)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3)  not loaded!
# specified material (material_2)  not loaded!
# specified material (material_1)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_5_24)  not loaded!
# specified material (material_6_24)  not loaded!
# specified material (material_7_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_8_24)  not loaded!
# specified material (material_9_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_15_24)  not loaded!
# specified material (material_12_24)  not loaded!
# specified material (material_11_24)  not loaded!
# specified material (material_14_24)  not loaded!
# specified material (material_13_24)  not loaded!
# specified material (material_10_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_4)  not loaded!
# specified material (material_3)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_6_24)  not loaded!
# specified material (material_5_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0)  not loaded!
# specified material (material)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_7_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_2_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_4_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material)  not loaded!
# specified material (material_0)  not loaded!
# specified material (material_1)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_6_24)  not loaded!
# specified material (material_5_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_8_24)  not loaded!
# specified material (material_7_24)  not loaded!
# specified material (material_2_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material)  not loaded!
# ...
# Mesh is non-watertight for contained point query!
# specified material (material)  not loaded!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# specified material (material_5)  not loaded!
# specified material (material_6)  not loaded!
# specified material (material_4)  not loaded!
# specified material (material_8)  not loaded!
# specified material (material_3)  not loaded!
# specified material (material_2)  not loaded!
# specified material (material_9)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0)  not loaded!
# specified material (material)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_2_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_5_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_2_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2)  not loaded!
# specified material (material_1)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# specified material (material)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_4_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_4)  not loaded!
# specified material (material_3)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3)  not loaded!
# specified material (material_2)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_4_24)  not loaded!
# specified material (material_2_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material)  not loaded!
# specified material (material_0)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_3_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_2_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2)  not loaded!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0)  not loaded!
# specified material (material)  not loaded!
# specified material (material_2)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0)  not loaded!
# specified material (material)  not loaded!
# specified material (material_1)  not loaded!
# specified material (material_2)  not loaded!
# specified material (material_3)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_3_24)  not loaded!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_2_24)  not loaded!
# specified material (material_0_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0_24)  not loaded!
# specified material (material_2_24)  not loaded!
# specified material (material_1_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_1_24)  not loaded!
# specified material (material_0_24)  not loaded!
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_0)  not loaded!
# specified material (material)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material_2)  not loaded!
# specified material (material_1)  not loaded!
# specified material (material_4)  not loaded!
# specified material (material_3)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_3)  not loaded!
# specified material (material_6)  not loaded!
# specified material (material_5)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material_4)  not loaded!
# specified material (material_3)  not loaded!
# specified material (material_2)  not loaded!
# specified material (material_1)  not loaded!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
# specified material (material)  not loaded!
# specified material (material_2)  not loaded!
# specified material (material_1)  not loaded!
# specified material (material_0)  not loaded!
# Mesh is non-watertight for contained point query!
# specified material (material)  not loaded!
# specified material (material_1)  not loaded!
# concatenating texture: may result in visual artifacts
# Mesh is non-watertight for contained point query!
